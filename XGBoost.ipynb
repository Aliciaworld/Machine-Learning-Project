# %% [markdown]
# # Build XGBoost

# %% [markdown]
# ## 1. Preprocessing

# %% [markdown]
# 1. Remove all the features that will not help creat an effective XGBoost model
#
#
# 2. Reformat the columns names(tree can't have name separated by ' ')
#
#
# 3. Identify missing values(missing values are fine when we do exploratory data analysis(EDA), but have to be filled in ML models)
#
#
# 4. Transfer "object" to "numeric"(to those that seemed to be numeric but dtype showed to be object: **pd.to_numeric()**)
#
#
# 5. Transfer **categorical** features to **numeric** features
#
#
# 6. For imbalanced data, using "stratify = y" to maintain the same percentage in bothin training and testing set.

# %% [markdown]
# ## 2. Model

# %% [markdown]
# #### Split the data
# x_train, x_test, y_train, y_test = train_test_split(x,y,random_state = 42, stratify = y)

# %% [markdown]
# #### Build the model

# %% [raw]
# # This is for classification problem
# import xgboost as xgb
# clf_xgb = xgb.XGBClassifier(objective = 'binary:logistic',
#                    missing = None,
#                    seed = 42)

# %% [raw]
# # This is for regression problem
# import xgboost as xgb
# reg_xgb = xgb.XGBRegressor（objective = 'reg:linear'）

# %% [markdown]
# #### Fit the model

# %% [raw]
# clf_xgb .fit(x_train,
#          y_train,
#          verbose = True,
#          early_stopping_rounds = 10,
#          eval_metric = 'aucpr',
#          eval_set = [(x_test, y_test)])

# %% [markdown]
# #### Check the model performance

# %% [raw]
# from sklearn.metric import plot_confusion_matrix
# plot_confusion_matrix(clf_xgb,
#                x_test,
#                y_test,
#                values_format = 'd',
#                display_labels = ['??', '??'])
#
# # the last two parameters are to make the confusion_matrix pretty.

# %% [markdown]
# #### Tune hyper-parameters

# %% [markdown]
# - **GridSearchCV()**: there are many hyperparameters to optimize, use GridSearchCV to test all possible combinations of the parameters
#
#
# - **scale_pos_weight**: help with imbalanced data
#
#
# - **gamma**: the parameter that encourages pruning
#
#
# - **reg_lambda**: the regulation parameter lambda
#
#
# - **n_jobs**: jobs that can be operated at the same time

# %% [raw]
# param_grid = {'max_depth': [3, 4, 5],
#           'learning_rate': [0.1, 0.001, 0.05],
#           'gamma': [0, 0.25, 1.0],
#           'reg_lambda': [0, 1.0, 10.0],
#           'scale_pos_weight': [1, 3, 5]}
# # If result showed some parameters are at the end of their range, continue optimise.
#
# # To speed up cross-validation, to further prevent overfitting, we only use a random subset of the data(90%) and a random subset of the features (50%) per tree.
#
# clf_xgb = xgb.XGBClassifier(objective = 'binary:logistic',
#                    seed = 42,
#                    subsample = 0.9,
#                    colsample_bytree = 0.5)
#
# optimal_params = GridSearchCV(estimator = clf_xgb,
#                     param_grid = param_grid,
#                     scoring = 'roc_auc',
#                     verbose = 0,
#                     n_jobs = 10,
#                     cv = 3)

# %% [markdown]
# #### Fit again after hyperparameter tune to get the best parameters

# %% [raw]
# optimal_params.fit(x_train,
#              y_train,
#              verbose = True,
#              early_stopping_rounds = 10,
#              eval_metric = 'auc',
#              eval_set = [(x_test, y_test)]
#
# optimal_params.best_params_

# %% [markdown]
# #### Using optimized parameters to build the fianl XGBoost model

# %% [raw]
# clf_xgb = xgb.XGBClassifier(objective = 'binary:logistic',
#                    seed = 42,
#                    subsample = 0.9,
#                    colsample_bytree = 0.5,
#
#                    max_depth = 4,
#                    learning_rate = 0.1,
#                    gamma = 0.25,
#                    reg_lambda = 10,
#                    scale_pos_weight = 3)

# %% [raw]
# clf_xgb.fit(x_train,
#         y_train,
#         verbose = True,
#         early_stopping_rounds = 10,
#         eval_metric = 'aucpr'
#         eval_set = [(x_test, y_test])

# %% [raw]
# from sklearn.metric import plot_confusion_matrix
# plot_confusion_matrix(clf_xgb,
#                x_test,
#                y_test,
#                values_format = 'd',
#                display_labels = ['??', '??'])
#
# # the last two parameters are to make the confusion_matrix pretty.

# %% [markdown]
# If want to get information, like gain and cover etc, at each node in the first tree, we just build the first tree(n_estimators = 1), otherwise we'll get the average over all the trees.
